# %% [markdown]
# <a href="https://colab.research.google.com/github/Shambhurajdesai/basics/blob/main/some_basic_methods_of_wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv('/content/drive/MyDrive/imdb.csv')

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.drop('id',axis=1,inplace=True)

# %%
#create three dataframes
df1 = df[df['runtime']>150]
df2 = df[(df['runtime']<150) & (df['runtime']>100)]
df3 = df[df['runtime']<100]

# %%
df1.head()
# Out:
#     belongs_to_collection    budget  \
# 47                    NaN  44000000
# 51                    NaN  12000000
# 76                    NaN    500000
# 97                    NaN         0
# 107                   NaN  72000000
#
#                                                 genres  \
# 47   [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51   [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97   [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                         homepage    imdb_id original_language  \
# 47   http://thehatefuleight.com/  tt3460252                en
# 51                           NaN  tt0059243                en
# 76                           NaN  tt0242572                ta
# 97                           NaN  tt1772980                ru
# 107                          NaN  tt0112573                en
#
# ...

# %%
df2.head()
# Out:
#                                 belongs_to_collection    budget  \
# 1   [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2                                                 NaN   3300000
# 3                                                 NaN   1200000
# 4                                                 NaN         0
# 10  [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
#
#                                                genres  \
# 1   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                       [{'id': 18, 'name': 'Drama'}]
# 3   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 10                      [{'id': 18, 'name': 'Drama'}]
#
#                              homepage    imdb_id original_language  \
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# ...

# %%
df3.head()
# Out:
#                                belongs_to_collection    budget  \
# 0  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 5                                                NaN   8000000
# 6                                                NaN  14000000
# 7                                                NaN         0
# 9                                                NaN   6000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 7                [{'id': 99, 'name': 'Documentary'}]
# 9  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 5                                 NaN  tt0093743                en
# ...

# %%
concat_runtime = pd.concat([df1,df2,df3])
concat_runtime
# Out:
#      belongs_to_collection    budget  \
# 47                     NaN  44000000
# 51                     NaN  12000000
# 76                     NaN    500000
# 97                     NaN         0
# 107                    NaN  72000000
# ...                    ...       ...
# 2987                   NaN         0
# 2988                   NaN         0
# 2989                   NaN         0
# 2990                   NaN         0
# 2998                   NaN  42000000
#
#                                                  genres  \
# 47    [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 51    [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 76    [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 97    [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 107   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# ...                                                 ...
# 2987  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2988                      [{'id': 18, 'name': 'Drama'}]
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  604 non-null    object
#  1   budget                 3000 non-null   int64
#  2   genres                 2993 non-null   object
#  3   homepage               946 non-null    object
#  4   imdb_id                3000 non-null   object
#  5   original_language      3000 non-null   object
#  6   original_title         3000 non-null   object
#  7   overview               2992 non-null   object
#  8   popularity             3000 non-null   float64
#  9   poster_path            2999 non-null   object
#  10  production_companies   2844 non-null   object
#  11  production_countries   2945 non-null   object
#  12  release_date           3000 non-null   object
#  13  runtime                2998 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %%
df.shape
# Out:
# (3000, 22)

# %%
df1.shape,df2.shape,df3.shape
# Out:
# ((127, 22), (1586, 22), (1178, 22))

# %%
# list_of_dfs = []
# for name_of_dfs in concat_runtime:
#   df = pd.read_csv("")
#   list_of_dfs.append(df)
# list_of_dfs

# %%
#dataframes which consists the english movies
english_movies = df[df['original_language']=='en']
english_movies

long_movies = df.loc[df['runtime']>100, ['imdb_id','original_language']]

# %%
english_movies.shape
# Out:
# (2575, 22)

# %%
long_movies.shape
# Out:
# (1721, 2)

# %%
type(long_movies)
# Out:
# pandas.core.frame.DataFrame

# %%
merged_IJ_df = pd.merge(english_movies,long_movies,how='inner',left_on='imdb_id',right_on='imdb_id')
merged_IJ_df
# Out:
#                                   belongs_to_collection    budget  \
# 0     [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 1                                                   NaN   3300000
# 2     [{'id': 1575, 'name': 'Rocky Collection', 'pos...   1000000
# 3                                                   NaN  15000000
# 4     [{'id': 91698, 'name': 'Chili Palmer Collectio...  53000000
# ...                                                 ...       ...
# 1431                                                NaN  60000000
# 1432                                                NaN         0
# 1433                                                NaN         0
# 1434                                                NaN  65000000
# 1435                                                NaN  35000000
#
#                                                  genres  \
# 0     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1                         [{'id': 18, 'name': 'Drama'}]
# ...

# %%
temp_df = df[(df['original_language']=='en') & (df['runtime']>100)]
temp_df.shape
# Out:
# (1436, 22)

# %%
df.original_language.value_counts()
# Out:
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# nl       6
# pt       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# ml       2
# pl       2
# te       2
# fi       2
# ur       1
# he       1
# el       1
# ar       1
# nb       1
# vi       1
# mr       1
# cs       1
# sr       1
# bn       1
# id       1
# Name: original_language, dtype: int64

# %%
hindi_movies = df[df['original_language']=='hi']
long_HI_movies = df.loc[df['runtime']>100, ['imdb_id','original_language']]

# %%
merge_IJ_HI = pd.merge(hindi_movies,long_HI_movies,how ='inner',left_on='imdb_id',right_on='imdb_id')

# %%
merge_IJ_HI.shape
# Out:
# (42, 23)

# %%
temp1_hi = df[(df['original_language']=='hi') & (df['runtime']>100)]
temp1_hi.shape
# Out:
# (42, 22)

# %%
df.budget.max()
# Out:
# 380000000

# %%
df.budget.min()
# Out:
# 0

# %%
df[df['budget']<1000000]
# Out:
#                                   belongs_to_collection  budget  \
# 4                                                   NaN       0
# 7                                                   NaN       0
# 8     [{'id': 256377, 'name': 'The Muppet Collection...       0
# 11    [{'id': 48190, 'name': 'Revenge of the Nerds C...       0
# 15                                                  NaN  500000
# ...                                                 ...     ...
# 2989                                                NaN       0
# 2990                                                NaN       0
# 2994                                                NaN       0
# 2995                                                NaN       0
# 2996                                                NaN       0
#
#                                                  genres  \
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 7                   [{'id': 99, 'name': 'Documentary'}]
# ...
